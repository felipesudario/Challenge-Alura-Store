# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
loja2.head()
loja3.head()
loja4.head()
# Out:
#                Produto Categoria do Produto    Preço      Frete  \
# 0          Lava louças     eletrodomesticos  1446.46  74.604083
# 1             Cama box               moveis   631.70  33.919251
# 2     Bola de basquete      esporte e lazer    31.54   0.000000
# 3  Modelagem preditiva               livros    76.93   1.680730
# 4       Fone de ouvido          eletronicos   185.14   7.442587
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     11/11/2022    Rafael Costa              SP                    4
# 1     03/01/2020    Thiago Silva              GO                    5
# 2     25/12/2022   Larissa Alves              MG                    5
# 3     23/11/2021  Lucas Oliveira              MG                    3
# 4     25/04/2022   Bianca Santos              SP                    4
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       3 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
# faturamento_loja1 = loja['Preço'].sum()
# faturamento_loja2 = loja2['Preço'].sum()
# faturamento_loja3 = loja3['Preço'].sum()
# faturamento_loja4 = loja4['Preço'].sum()

# print(f"Faturamento Loja 1: R$ {faturamento_loja1:.2f}")
# print(f"Faturamento Loja 2: R$ {faturamento_loja2:.2f}")
# print(f"Faturamento Loja 3: R$ {faturamento_loja3:.2f}")
# print(f"Faturamento Loja 4: R$ {faturamento_loja4:.2f}")

import matplotlib.pyplot as plt

# ... (código anterior para calcular o faturamento das lojas) ...

# Criar o gráfico de barras
plt.figure(figsize=(8, 6))
bars = plt.bar(nomes_lojas, faturamento_lojas, color=['blue', 'green', 'red', 'purple'])
plt.title('Faturamento por Loja')
plt.xlabel('Loja')
plt.ylabel('Faturamento (R$)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Adicionar valores em cima das barras
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.05, f'R$ {yval:,.2f}', ha='center', va='bottom')

plt.show()

# %% [markdown]
# # 2. Vendas por Categoria

# %%
# Assumindo que a coluna de categoria se chama "Categoria" e a de preço "Preço"
vendas_por_categoria_loja1 = loja.groupby('Categoria do Produto')['Preço'].sum().reset_index()
vendas_por_categoria_loja2 = loja2.groupby('Categoria do Produto')['Preço'].sum().reset_index()
vendas_por_categoria_loja3 = loja3.groupby('Categoria do Produto')['Preço'].sum().reset_index()
vendas_por_categoria_loja4 = loja4.groupby('Categoria do Produto')['Preço'].sum().reset_index()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assumindo que a coluna de categoria se chama "Categoria do Produto" e a de preço "Preço"
vendas_por_categoria_loja1 = loja.groupby('Categoria do Produto')['Preço'].sum().reset_index()
vendas_por_categoria_loja2 = loja2.groupby('Categoria do Produto')['Preço'].sum().reset_index()
vendas_por_categoria_loja3 = loja3.groupby('Categoria do Produto')['Preço'].sum().reset_index()
vendas_por_categoria_loja4 = loja4.groupby('Categoria do Produto')['Preço'].sum().reset_index()

# Criar um gráfico de barras para cada loja
fig, axes = plt.subplots(2, 2, figsize=(12, 8))  # Cria uma figura com 4 subplots (2x2)

# Gráfico para Loja 1
axes[0, 0].bar(vendas_por_categoria_loja1['Categoria do Produto'], vendas_por_categoria_loja1['Preço'])
axes[0, 0].set_title('Vendas por Categoria - Loja 1')
axes[0, 0].set_xlabel('Categoria do Produto')
axes[0, 0].set_ylabel('Faturamento (R$)')
axes[0, 0].tick_params(axis='x', rotation=45)

# Gráfico para Loja 2
axes[0, 1].bar(vendas_por_categoria_loja2['Categoria do Produto'], vendas_por_categoria_loja2['Preço'])
axes[0, 1].set_title('Vendas por Categoria - Loja 2')
axes[0, 1].set_xlabel('Categoria do Produto')
axes[0, 1].set_ylabel('Faturamento (R$)')
axes[0, 1].tick_params(axis='x', rotation=45)

# Gráfico para Loja 3
axes[1, 0].bar(vendas_por_categoria_loja3['Categoria do Produto'], vendas_por_categoria_loja3['Preço'])
axes[1, 0].set_title('Vendas por Categoria - Loja 3')
axes[1, 0].set_xlabel('Categoria do Produto')
axes[1, 0].set_ylabel('Faturamento (R$)')
axes[1, 0].tick_params(axis='x', rotation=45)

# Gráfico para Loja 4
axes[1, 1].bar(vendas_por_categoria_loja4['Categoria do Produto'], vendas_por_categoria_loja4['Preço'])
axes[1, 1].set_title('Vendas por Categoria - Loja 4')
axes[1, 1].set_xlabel('Categoria do Produto')
axes[1, 1].set_ylabel('Faturamento (R$)')
axes[1, 1].tick_params(axis='x', rotation=45)

plt.tight_layout()  # Ajusta o layout para evitar sobreposição
plt.show()

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assumindo que a coluna de avaliação se chama "Avaliação"
media_avaliacao_lojas = [loja['Avaliação da compra'].mean(),
                         loja2['Avaliação da compra'].mean(),
                         loja3['Avaliação da compra'].mean(),
                         loja4['Avaliação da compra'].mean()]
nomes_lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']

# Criar o gráfico de barras
plt.figure(figsize=(8, 6))
plt.bar(nomes_lojas, media_avaliacao_lojas, color=['blue', 'green', 'red', 'purple'])
plt.title('Média de Avaliação das Lojas')
plt.xlabel('Loja')
plt.ylabel('Avaliação Média')
plt.ylim(0, 5)  # Define o limite do eixo y para melhor visualização (opcional)

# Adicionar os valores da média em cima das barras
for i, media in enumerate(media_avaliacao_lojas):
    plt.text(i, media + 0.1, f'{media:.2f}', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assumindo que a coluna de produto se chama "Produto"
# Concatenar os DataFrames de todas as lojas
todos_produtos = pd.concat([loja['Produto'], loja2['Produto'],
                            loja3['Produto'], loja4['Produto']])

# Contar a frequência de cada produto
frequencia_produtos = todos_produtos.value_counts()

# Obter os produtos mais e menos vendidos (Top 5 e Bottom 5)
produtos_mais_vendidos = frequencia_produtos.head(5)
produtos_menos_vendidos = frequencia_produtos.tail(5)

# Criar gráficos de barras
fig, axes = plt.subplots(1, 2, figsize=(12, 6))  # 1 linha, 2 colunas

# Gráfico dos produtos mais vendidos
axes[0].bar(produtos_mais_vendidos.index, produtos_mais_vendidos.values)
axes[0].set_title('Produtos Mais Vendidos (Top 5)')
axes[0].set_xlabel('Produto')
axes[0].set_ylabel('Quantidade Vendida')
# Alteração: Usando 'horizontalalignment' ao invés de 'ha'
axes[0].tick_params(axis='x', rotation=45, labelrotation=45)

# Gráfico dos produtos menos vendidos
axes[1].bar(produtos_menos_vendidos.index, produtos_menos_vendidos.values)
axes[1].set_title('Produtos Menos Vendidos (Bottom 5)')
axes[1].set_xlabel('Produto')
axes[1].set_ylabel('Quantidade Vendida')
# Alteração: Usando 'horizontalalignment' ao invés de 'ha'
axes[1].tick_params(axis='x', rotation=45, labelrotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Calcular o frete médio para cada loja
frete_medio_loja1 = loja['Frete'].mean()
frete_medio_loja2 = loja2['Frete'].mean()
frete_medio_loja3 = loja3['Frete'].mean()
frete_medio_loja4 = loja4['Frete'].mean()

# Criar uma lista com os fretes médios e nomes das lojas
frete_medio_lojas = [frete_medio_loja1, frete_medio_loja2, frete_medio_loja3, frete_medio_loja4]
nomes_lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']

# Criar o gráfico de barras
plt.figure(figsize=(8, 6))
bars = plt.bar(nomes_lojas, frete_medio_lojas, color=['blue', 'green', 'red', 'purple'])
plt.title('Frete Médio por Loja')
plt.xlabel('Loja')
plt.ylabel('Frete Médio (R$)')

# Adicionar valores em cima das barras
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.05, f'R$ {yval:.2f}', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Assuming you have already loaded your data into DataFrames: loja, loja2, loja3, loja4

# Calculate key metrics for each store
faturamento_lojas = [loja['Preço'].sum(), loja2['Preço'].sum(), loja3['Preço'].sum(), loja4['Preço'].sum()]
media_avaliacao_lojas = [loja['Avaliação da compra'].mean(), loja2['Avaliação da compra'].mean(), loja3['Avaliação da compra'].mean(), loja4['Avaliação da compra'].mean()]
frete_medio_lojas = [loja['Frete'].mean(), loja2['Frete'].mean(), loja3['Frete'].mean(), loja4['Frete'].mean()]

# Assign weights to each factor (adjust as needed)
peso_faturamento = 0.5  # Revenue weight
peso_avaliacao = 0.3   # Average rating weight
peso_frete = 0.2      # Average shipping cost weight

# Calculate weighted scores for each store
nomes_lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
scores = []
for i in range(4):
    score = (faturamento_lojas[i] * peso_faturamento +
              media_avaliacao_lojas[i] * peso_avaliacao -  # Subtract shipping cost as lower is better
              frete_medio_lojas[i] * peso_frete)
    scores.append(score)

# Find the store with the highest score
melhor_loja_index = scores.index(max(scores))
melhor_loja = nomes_lojas[melhor_loja_index]

# Print the recommendation
print(f"A loja recomendada para Seu João é vender: {melhor_loja}")
# Out:
# A loja recomendada para Seu João é vender: Loja 1

# %%
import pandas as pd

# Assuming you have already loaded your data into DataFrames: loja, loja2, loja3, loja4

# Calculate key metrics for each store
faturamento_lojas = [loja['Preço'].sum(), loja2['Preço'].sum(), loja3['Preço'].sum(), loja4['Preço'].sum()]
media_avaliacao_lojas = [loja['Avaliação da compra'].mean(), loja2['Avaliação da compra'].mean(), loja3['Avaliação da compra'].mean(), loja4['Avaliação da compra'].mean()]
frete_medio_lojas = [loja['Frete'].mean(), loja2['Frete'].mean(), loja3['Frete'].mean(), loja4['Frete'].mean()]

# Assign weights to each factor (adjust as needed)
peso_faturamento = 0.5  # Revenue weight
peso_avaliacao = 0.3   # Average rating weight
peso_frete = 0.2      # Average shipping cost weight

# Calculate weighted inefficiency scores for each store
nomes_lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
inefficiency_scores = []
for i in range(4):
    score = (-faturamento_lojas[i] * peso_faturamento +  # Negate revenue for inefficiency
             -media_avaliacao_lojas[i] * peso_avaliacao + # Negate rating for inefficiency
              frete_medio_lojas[i] * peso_frete)
    inefficiency_scores.append(score)

# Find the store with the lowest efficiency (highest inefficiency score)
loja_menos_eficiente_index = inefficiency_scores.index(max(inefficiency_scores))
loja_menos_eficiente = nomes_lojas[loja_menos_eficiente_index]

# Print the result
print(f"A loja com menor eficiência é: {loja_menos_eficiente}")
# Out:
# A loja com menor eficiência é: Loja 4

# %%
# Calcular faturamento total (Preço * Quantidade de parcelas)
loja['faturamento'] = loja['Preço'] * loja['Quantidade de parcelas']
loja2['faturamento'] = loja2['Preço'] * loja2['Quantidade de parcelas']
loja3['faturamento'] = loja3['Preço'] * loja3['Quantidade de parcelas']
loja4['faturamento'] = loja4['Preço'] * loja4['Quantidade de parcelas']

# Calcular o ticket médio (faturamento total / Quantidade de parcelas)
ticket_medio_loja1 = loja['faturamento'].sum() / loja['Quantidade de parcelas'].sum()
ticket_medio_loja2 = loja2['faturamento'].sum() / loja2['Quantidade de parcelas'].sum()
ticket_medio_loja3 = loja3['faturamento'].sum() / loja3['Quantidade de parcelas'].sum()
ticket_medio_loja4 = loja4['faturamento'].sum() / loja4['Quantidade de parcelas'].sum()

# Calcular a avaliação média
avaliacao_media_loja1 = loja['Avaliação da compra'].mean()
avaliacao_media_loja2 = loja2['Avaliação da compra'].mean()
avaliacao_media_loja3 = loja3['Avaliação da compra'].mean()
avaliacao_media_loja4 = loja4['Avaliação da compra'].mean()

# Calcular o frete médio
frete_medio_loja1 = loja['Frete'].mean()
frete_medio_loja2 = loja2['Frete'].mean()
frete_medio_loja3 = loja3['Frete'].mean()
frete_medio_loja4 = loja4['Frete'].mean()

# Mostrar os resultados
print("Loja 1 - Faturamento Total: ", loja['faturamento'].sum())
print("Loja 1 - Ticket Médio: ", ticket_medio_loja1)
print("Loja 1 - Avaliação Média: ", avaliacao_media_loja1)
print("Loja 1 - Frete Médio: ", frete_medio_loja1)

print("\nLoja 2 - Faturamento Total: ", loja2['faturamento'].sum())
print("Loja 2 - Ticket Médio: ", ticket_medio_loja2)
print("Loja 2 - Avaliação Média: ", avaliacao_media_loja2)
print("Loja 2 - Frete Médio: ", frete_medio_loja2)

print("\nLoja 3 - Faturamento Total: ", loja3['faturamento'].sum())
print("Loja 3 - Ticket Médio: ", ticket_medio_loja3)
print("Loja 3 - Avaliação Média: ", avaliacao_media_loja3)
print("Loja 3 - Frete Médio: ", frete_medio_loja3)

print("\nLoja 4 - Faturamento Total: ", loja4['faturamento'].sum())
print("Loja 4 - Ticket Médio: ", ticket_medio_loja4)
print("Loja 4 - Avaliação Média: ", avaliacao_media_loja4)
print("Loja 4 - Frete Médio: ", frete_medio_loja4)
# Out:
# Loja 1 - Faturamento Total:  4563636.109999999
# Loja 1 - Ticket Médio:  657.3003183062076
# Loja 1 - Avaliação Média:  3.976685036032217
# Loja 1 - Frete Médio:  34.69180491551149
#
# Loja 2 - Faturamento Total:  4449584.18
# Loja 2 - Ticket Médio:  649.8589426025997
# Loja 2 - Avaliação Média:  4.037303942348453
# Loja 2 - Frete Médio:  33.62194065817927
#
# Loja 3 - Faturamento Total:  4325091.42
# Loja 3 - Ticket Médio:  617.781948293101
# Loja 3 - Avaliação Média:  4.048325561678677
# Loja 3 - Frete Médio:  33.07446427411743
#
# Loja 4 - Faturamento Total:  4131753.1399999997
# Loja 4 - Ticket Médio:  605.0304788402401
# Loja 4 - Avaliação Média:  3.9957591178965224
# Loja 4 - Frete Médio:  31.278997081841727

# %%
# # Verificando as colunas dos DataFrames
# print(loja.columns)
# print(loja2.columns)
# print(loja3.columns)
# print(loja4.columns)

# %% [markdown]
# # Relatório de Eficiência das Lojas
#
# Este relatório analisa a eficiência de quatro lojas com base nas seguintes métricas:
# - **Faturamento Total**
# - **Ticket Médio**
# - **Avaliação Média**
# - **Frete Médio**
#
# ## Dados das Lojas
#
# ### Loja 1
# - **Faturamento Total**: R$ 4.563.636,11
# - **Ticket Médio**: R$ 657,30
# - **Avaliação Média**: 3,98
# - **Frete Médio**: R$ 34,69
#
# ### Loja 2
# - **Faturamento Total**: R$ 4.449.584,18
# - **Ticket Médio**: R$ 649,86
# - **Avaliação Média**: 4,04
# - **Frete Médio**: R$ 33,62
#
# ### Loja 3
# - **Faturamento Total**: R$ 4.325.091,42
# - **Ticket Médio**: R$ 617,78
# - **Avaliação Média**: 4,05
# - **Frete Médio**: R$ 33,07
#
# ### Loja 4
# - **Faturamento Total**: R$ 4.131.753,14
# - **Ticket Médio**: R$ 605,03
# - **Avaliação Média**: 3,99
# - **Frete Médio**: R$ 31,28
#
# ## Análise Comparativa
#
# ### Faturamento Total:
# - **Loja 1** apresenta o maior **faturamento total** (R$ 4.563.636,11).
# - **Loja 4** apresenta o menor **faturamento total** (R$ 4.131.753,14).
#
# **Conclusão**: Lojas com maior faturamento são consideradas mais eficientes, já que indicam um volume maior de vendas.
#
# ### Ticket Médio:
# - **Loja 1** tem o **maior ticket médio** (R$ 657,30).
# - **Loja 4** tem o **menor ticket médio** (R$ 605,03).
#
# **Conclusão**: Um ticket médio maior pode indicar vendas de maior valor, o que favorece a eficiência da loja.
#
# ### Avaliação Média:
# - **Loja 3** tem a **melhor avaliação média** (4,05).
# - **Loja 2** vem em segundo lugar (4,04).
# - **Loja 1** tem uma **avaliação média** de 3,98.
# - **Loja 4** tem a **avalição média** mais baixa (3,99).
#
# **Conclusão**: Avaliações mais altas são indicativos de uma melhor experiência para o cliente e, portanto, mais eficientes.
#
# ### Frete Médio:
# - **Loja 4** tem o **menor frete médio** (R$ 31,28), o que implica em menor custo logístico.
# - **Loja 1** tem o **maior frete médio** (R$ 34,69).
#
# **Conclusão**: Custos logísticos menores, representados por um frete médio baixo, são indicativos de uma operação mais eficiente.
#
# ## Conclusão Final
#
# Com base nas métricas analisadas, a **Loja 4** é a **menos eficiente**, pois apresenta:
#
# - **Menor faturamento total**.
# - **Menor ticket médio**.
# - **Avaliação média razoável**, mas não tão alta quanto as outras.
#
# Embora a **Loja 4** tenha o **menor frete médio**, isso não compensa os outros pontos negativos. A combinação de baixo faturamento e ticket médio, juntamente com uma avaliação média baixa, leva à conclusão de que a **Loja 4** possui a menor eficiência.
